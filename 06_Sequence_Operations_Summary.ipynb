# %% [markdown]
# # 6️⃣ Summary Table
#
#
# | Sequence Type | Mutable | Ordered | Allows Duplicates | Example    |
# | ------------- | ------- | ------- | ----------------- | ---------- |
# | List          | Yes     | Yes     | Yes               | [1,2,3]    |
# | Tuple         | No      | Yes     | Yes               | (1,2,3)    |
# | Range         | No      | Yes     | Yes               | range(0,5) |
# | String        | No      | Yes     | Yes               | "Hello"    |
